# %%
import os
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px
os.chdir("E:/Masaüstü/bootcamp")

# %%
df=pd.read_csv("https://raw.githubusercontent.com/UVBMOB/Ankara2019/master/Verisetleri/hmelq.csv")
df.head()
# Out:
#    bad   loan   mortdue     value   reason  job   yoj  derog  delinq   clage  \
# 0    0  81200   18834.0  108355.0  HomeImp  NaN  28.0    0.0     0.0  139.14
# 1    0  12600  103960.0  127384.0  DebtCon  NaN   2.0    0.0     0.0  129.02
# 2    0  18000   46865.0   61266.0  DebtCon  NaN   5.0    0.0     0.0  102.59
# 3    0  10300   57676.0   71027.0  DebtCon  NaN  19.0    0.0     0.0  157.52
# 4    0   9400   56508.0   78358.0  DebtCon  NaN  17.0    0.0     0.0  141.93
#
#    ninq  clno  debtinc
# 0   0.0  14.0   34.042
# 1   0.0  25.0   34.479
# 2   2.0   9.0   26.354
# 3   1.0  11.0   33.992
# 4   0.0  11.0   32.327

# %%
df.tail()
# Out:
#       bad   loan   mortdue    value   reason   job  yoj  derog  delinq  \
# 3571    1   8400   31800.0  72000.0  DebtCon  Self  NaN    0.0     2.0
# 3572    1  21600  154991.0      NaN  DebtCon  Self  NaN    2.0     4.0
# 3573    1  24000   35000.0      NaN  DebtCon  Self  3.0    1.0     0.0
# 3574    1  10000       NaN  25010.0  HomeImp  Self  5.0    0.0     3.0
# 3575    1   5900       NaN  28000.0  DebtCon  Self  1.0    2.0     1.0
#
#        clage  ninq  clno  debtinc
# 3571  187.27   1.0  21.0      NaN
# 3572  165.60   0.0  43.0   38.015
# 3573  177.50   0.0  16.0      NaN
# 3574  326.13   4.0  17.0      NaN
# 3575   36.77   1.0   8.0      NaN

# %%
df.reason.value_counts()
# Out:
# DebtCon    2371
# HomeImp    1058
# Name: reason, dtype: int64

# %%
df.columns
# Out:
# Index(['bad', 'loan', 'mortdue', 'value', 'reason', 'job', 'yoj', 'derog',
#        'delinq', 'clage', 'ninq', 'clno', 'debtinc'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3576 entries, 0 to 3575
# Data columns (total 13 columns):
# bad        3576 non-null int64
# loan       3576 non-null int64
# mortdue    3262 non-null float64
# value      3512 non-null float64
# reason     3429 non-null object
# job        3409 non-null object
# yoj        3264 non-null float64
# derog      3149 non-null float64
# delinq     3225 non-null float64
# clage      3397 non-null float64
# ninq       3273 non-null float64
# clno       3443 non-null float64
# debtinc    2809 non-null float64
# dtypes: float64(9), int64(2), object(2)
# memory usage: 363.3+ KB

# %%
plt.hist(df.bad)
plt.xlabel("bad customer")
plt.ylabel("frekans")
plt.show()

# %%
plt.hist(df.loan)
plt.xlabel("loan")
plt.ylabel("frekans")
plt.show()

# %%
f,ax=plt.subplots(figsize=(20,20))
sns.heatmap(df.corr(),annot=True,linewidths=.5,fmt=".3f",ax=ax)
plt.show()

# %% [markdown]
# #yorum

# %%
df.describe().T
# Out:
#           count           mean           std      min       25%        50%  \
# bad      3576.0       0.199385      0.399594     0.00      0.00      0.000
# loan     3576.0   18529.697987  11262.834060  1100.00  11000.00  16200.000
# mortdue  3262.0   74013.907992  44016.833772  2619.00  46700.25  65858.000
# value    3512.0  101076.922759  54865.275351  8800.00  65753.00  89183.000
# yoj      3264.0       8.832644      7.568046     0.00      3.00      7.000
# derog    3149.0       0.261670      0.865178     0.00      0.00      0.000
# delinq   3225.0       0.432558      1.099230     0.00      0.00      0.000
# clage    3397.0     179.832529     87.066198     0.49    115.60    173.640
# ninq     3273.0       1.186373      1.728723     0.00      0.00      1.000
# clno     3443.0      21.507116     10.167490     0.00     15.00     20.000
# debtinc  2809.0      33.831737      9.061837     0.72     29.14     34.747
#
#                75%         max
# bad           0.00       1.000
# ...

# %%
liste= [str(i) for i in df.columns  if str(i) !="job" and str(i)!="reason" ]

# %%
for i in liste[1:]:
    df.boxplot(column=i,by="bad",figsize=(6,6))

# %% [markdown]
# #yorum

# %%
bad_job=pd.crosstab(index=df.bad,columns=df.job)
bad_job
bad_job.index=["good","bad"]

# %%
bad_job
# Out:
# job   Mgr  Office  Other  ProfEx  Sales  Self
# good  354     494   1099     639     43    81
# bad   107      75    332     128     23    34

# %% [markdown]
# #yorum

# %%
bad_reasons=pd.crosstab(index=df.bad,columns=df.reason)
bad_reasons
# Out:
# reason  DebtCon  HomeImp
# bad
# 0          1931      814
# 1           440      244

# %%
df.head()
# Out:
#    bad   loan   mortdue     value   reason  job   yoj  derog  delinq   clage  \
# 0    0  81200   18834.0  108355.0  HomeImp  NaN  28.0    0.0     0.0  139.14
# 1    0  12600  103960.0  127384.0  DebtCon  NaN   2.0    0.0     0.0  129.02
# 2    0  18000   46865.0   61266.0  DebtCon  NaN   5.0    0.0     0.0  102.59
# 3    0  10300   57676.0   71027.0  DebtCon  NaN  19.0    0.0     0.0  157.52
# 4    0   9400   56508.0   78358.0  DebtCon  NaN  17.0    0.0     0.0  141.93
#
#    ninq  clno  debtinc
# 0   0.0  14.0   34.042
# 1   0.0  25.0   34.479
# 2   2.0   9.0   26.354
# 3   1.0  11.0   33.992
# 4   0.0  11.0   32.327

# %%
#datanın loan attribute ü normal dağılıyor mu

import pylab
import scipy.stats as stats
stats.probplot(df.loan,dist="norm",plot=pylab)
# Out:
# ((array([-3.54836637, -3.30762727, -3.17465905, ...,  3.17465905,
#           3.30762727,  3.54836637]),
#   array([ 1100,  1300,  1500, ..., 89200, 89800, 89900], dtype=int64)),
#  (10386.167748017171, 18529.697986577183, 0.9214615778562602))

# %% [markdown]
# Dağılım normal değil

# %%
#datanın mortdue attribute ü normal dağılıyor mu
stats.probplot(df.mortdue,dist="norm",plot=pylab)
# Out:
# ((array([-3.54836637, -3.30762727, -3.17465905, ...,  3.17465905,
#           3.30762727,  3.54836637]),
#   array([2619., 2800., 3372., ...,   nan,   nan,   nan])),
#  (nan, nan, nan))

# %%
stats.probplot(df.value,dist="norm",plot=pylab)
# Out:
# ((array([-3.54836637, -3.30762727, -3.17465905, ...,  3.17465905,
#           3.30762727,  3.54836637]),
#   array([ 8800.,  9500., 11550., ...,    nan,    nan,    nan])),
#  (nan, nan, nan))

# %%
stats.probplot(df.yoj,dist="norm",plot=pylab)
# Out:
# ((array([-3.54836637, -3.30762727, -3.17465905, ...,  3.17465905,
#           3.30762727,  3.54836637]),
#   array([ 0.,  0.,  0., ..., nan, nan, nan])),
#  (nan, nan, nan))

# %%
stats.probplot(df.clage,dist="norm",plot=pylab)
# Out:
# ((array([-3.54836637, -3.30762727, -3.17465905, ...,  3.17465905,
#           3.30762727,  3.54836637]),
#   array([0.49, 2.03, 3.04, ...,  nan,  nan,  nan])),
#  (nan, nan, nan))

# %%
stats.probplot(df.debtinc,dist="norm",plot=pylab)
# Out:
# ((array([-3.54836637, -3.30762727, -3.17465905, ...,  3.17465905,
#           3.30762727,  3.54836637]),
#   array([0.72 , 1.029, 1.566, ...,   nan,   nan,   nan])),
#  (nan, nan, nan))

# %%
#shapiro test ile tekrar normal dağılımdan gelip gelmediğini kontrol ediyorum
from scipy.stats import shapiro
shapiro(df.loan)
#normal dağılımdan gelmiyor
# Out:
# (0.8493258953094482, 0.0)

# %%
stats.t.cdf(x=0.8493258953094482, df=len(df.loan)-1)
# Out:
# 0.8021215773766895

# %%
shapiro(df.debtinc)
#?
# Out:
# (nan, 1.0)

# %%
from scipy.stats import levene 
levene(df.loan, df.value)
# Out:
# LeveneResult(statistic=nan, pvalue=nan)

# %%
df.head()
# Out:
#    bad   loan   mortdue     value   reason  job   yoj  derog  delinq   clage  \
# 0    0  81200   18834.0  108355.0  HomeImp  NaN  28.0    0.0     0.0  139.14
# 1    0  12600  103960.0  127384.0  DebtCon  NaN   2.0    0.0     0.0  129.02
# 2    0  18000   46865.0   61266.0  DebtCon  NaN   5.0    0.0     0.0  102.59
# 3    0  10300   57676.0   71027.0  DebtCon  NaN  19.0    0.0     0.0  157.52
# 4    0   9400   56508.0   78358.0  DebtCon  NaN  17.0    0.0     0.0  141.93
#
#    ninq  clno  debtinc
# 0   0.0  14.0   34.042
# 1   0.0  25.0   34.479
# 2   2.0   9.0   26.354
# 3   1.0  11.0   33.992
# 4   0.0  11.0   32.327
